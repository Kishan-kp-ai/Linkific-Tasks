# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishan-kp-ai/Linkific-Tasks/blob/main/Day%2020/tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculator(expression):
    return "Calculator Tool"


def web_search(query):
    return "Web Search Tool"


def database_tool(query):
    return "Database Tool"


def file_reader(filename):
    return "File Reader Tool"


def weather_tool(location):
    return "Weather Tool"


def email_tool(message):
    return "Email Tool"


def date_tool(query):
    return "Date Tool"


def data_analyzer(dataset):
    return "Data Analyzer Tool"


def select_tool(request):

    request = request.lower()

    if any(word in request for word in ["calculate", "multiply", "add", "subtract"]):
        return calculator(request)

    elif any(word in request for word in ["weather", "temperature", "rain"]):
        return weather_tool(request)

    elif any(word in request for word in ["email", "mail", "send"]):
        return email_tool(request)

    elif any(word in request for word in ["database", "customer", "user record"]):
        return database_tool(request)

    elif any(word in request for word in ["pdf", "file", "document"]):
        return file_reader(request)

    elif any(word in request for word in ["days", "date", "tomorrow"]):
        return date_tool(request)

    elif any(word in request for word in ["average", "highest", "dataset", "analyze"]):
        return data_analyzer(request)

    elif any(word in request for word in ["search", "latest", "news"]):
        return web_search(request)

    else:
        return "No suitable tool found"


# Test user requests
requests = [
    "Calculate 50 + 25",
    "What is the latest AI news?",
    "Find customer 101",
    "Read this PDF file",
    "What is the weather today?",
    "Send an email to my manager",
    "How many days until New Year?",
    "Find the average marks in the dataset"
]

for request in requests:
    tool = select_tool(request)

    print("User Request:", request)
    print("Selected Tool:", tool)
    print("-" * 50)
# Out:
# User Request: Calculate 50 + 25
# Selected Tool: Calculator Tool
# --------------------------------------------------
# User Request: What is the latest AI news?
# Selected Tool: Web Search Tool
# --------------------------------------------------
# User Request: Find customer 101
# Selected Tool: Database Tool
# --------------------------------------------------
# User Request: Read this PDF file
# Selected Tool: File Reader Tool
# --------------------------------------------------
# User Request: What is the weather today?
# Selected Tool: Weather Tool
# --------------------------------------------------
# User Request: Send an email to my manager
# Selected Tool: Email Tool
# --------------------------------------------------
# User Request: How many days until New Year?
# Selected Tool: Date Tool
# --------------------------------------------------
# User Request: Find the average marks in the dataset
# Selected Tool: Data Analyzer Tool
# ...

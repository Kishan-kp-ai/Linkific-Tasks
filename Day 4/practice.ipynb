# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishan-kp-ai/Linkific-Tasks/blob/main/Day%204/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([1,2,3,4])

print(arr);
# Out:
# [1 2 3 4]

# %%
arr2 = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
print(arr2[1, 1])
# Out:
# 50

# %%
print(arr2[2, 0])
# Out:
# 70

# %%
print(arr2[0:2])
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(arr2[:, 1])
# Out:
# [20 50 80]

# %%
arr = np.array([10, 20, 30, 40, 50])

# %%
print(np.sum(arr))
print(np.mean(arr))
print(np.max(arr))
print(np.min(arr))
# Out:
# 150
# 30.0
# 50
# 10
